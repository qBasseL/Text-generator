# %%
# !pip install transformers torch

# %% [markdown]
# **اسختدام model gpt2-xl**

# %%
from transformers import GPT2LMHeadModel, GPT2Tokenizer

model_name = 'gpt2-xl'
tokenizer = GPT2Tokenizer.from_pretrained(model_name)
model = GPT2LMHeadModel.from_pretrained(model_name)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/689 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/6.43G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]

# %%
def generate_text(prompt, max_length=100):

    inputs = tokenizer.encode(prompt, return_tensors='pt')

    outputs = model.generate(
        inputs,
        max_length=max_length,
        num_return_sequences=1,
        pad_token_id=tokenizer.eos_token_id
    )

    return tokenizer.decode(outputs[0], skip_special_tokens=True)

# %%
prompt = "Once upon a time in a land far away"
generated_text = generate_text(prompt=prompt, max_length=100)
print("Generated Text:")
print(generated_text)
# Out:
# Generated Text:
# Once upon a time in a land far away, there was a king who had a daughter who was very beautiful. She was very kind and gentle, and she loved her father very much. One day, the king was out hunting and he came across a beautiful, white horse. He was so excited that he ran up to the horse and gave it a kiss. The horse then ran off into the forest, and the king was left alone. He was so sad that he went to the forest and

# %%
prompt = input("Enter your prompt: ")
generated_text = generate_text(prompt, max_length=100)
print("\nGenerated Text:")
print(generated_text)
# Out:
# Enter your prompt: the sun
#
# Generated Text:
# the sun, the moon, and the stars, and the earth, and the sea, and all that is in them, and the birds in the sky, and the fishes in the sea, and the cattle, and the creeping things that creep on the earth, and the fowls of the air, and the fishes that are in the sea, and the cattle that are on the earth, and all that is in them, and the birds of the air, and the beasts of the earth

# %%
import json

def save_conversation(history, filename='conversation_history.json'):
    with open(filename, 'w') as file:
        json.dump(history, file, indent=4)

def load_conversation(filename='conversation_history.json'):
    try:
        with open(filename, 'r') as file:
            return json.load(file)
    except FileNotFoundError:
        return []

conversation_history = load_conversation()
conversation_history.append("New conversation started.")
save_conversation(conversation_history)

# %% [markdown]
# # **first try for the code so we did it withou the need of the input just to test it**

# %%
import json
from IPython.display import HTML

def generate_text_styled(prompt, max_length=100):
    generated_text = generate_text(prompt, max_length)
    return f"<b>Prompt:</b> {prompt}<br><b>Generated Text:</b> {generated_text}"

styled_text = generate_text_styled("Once upon a time in a land far away", max_length=100)
display(HTML(styled_text))
# Out:
# <b>Prompt:</b> Once upon a time in a land far away<br><b>Generated Text:</b> Once upon a time in a land far away, there was a king who had a daughter who was very beautiful. She was very kind and gentle, and she loved her father very much. One day, the king was out hunting and he came across a beautiful, white horse. He was so excited that he ran up to the horse and gave it a kiss. The horse then ran off into the forest, and the king was left alone. He was so sad that he went to the forest and

# %% [markdown]
# # **here we added the input option so you could type whatever you want and you can have a full coversation with the model till you write exit**

# %%
import os
from huggingface_hub import login


login(token=os.getenv("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"))

from transformers import GPT2LMHeadModel, GPT2Tokenizer
import torch
from IPython.display import display, HTML


tokenizer = GPT2Tokenizer.from_pretrained('gpt2-xl')
model = GPT2LMHeadModel.from_pretrained('gpt2-xl')

def generate_text(prompt, max_length=100):

    inputs = tokenizer.encode(prompt, return_tensors='pt')


    attention_mask = torch.ones(inputs.shape, dtype=torch.long)


    outputs = model.generate(
        inputs,
        attention_mask=attention_mask,
        max_length=max_length,
        num_return_sequences=1,
        pad_token_id=tokenizer.eos_token_id
    )


    return tokenizer.decode(outputs[0], skip_special_tokens=True)

def generate_text_styled(prompt, max_length=100):

    generated_text = generate_text(prompt, max_length)

    styled_text = f"""
    <div style="font-family: Arial, sans-serif; padding: 10px; border: 1px solid #ddd; border-radius: 5px; margin-bottom: 20px;">
        <b>Prompt:</b> <span style="color: #007bff;">{prompt}</span><br>
        <b>Generated Text:</b> <span style="color: #333;">{generated_text}</span>
    </div>
    """
    return styled_text

prompt = "Once upon a time in a land far away"
styled_output = generate_text_styled(prompt, max_length=100)
display(HTML(styled_output))
# Out:
# ...
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
#     <div style="font-family: Arial, sans-serif; padding: 10px; border: 1px solid #ddd; border-radius: 5px; margin-bottom: 20px;">
#         <b>Prompt:</b> <span style="color: #007bff;">Once upon a time in a land far away</span><br>
# ...

# %%
from transformers import BartTokenizer, BartForConditionalGeneration

summarizer_tokenizer = BartTokenizer.from_pretrained('facebook/bart-large-cnn')
summarizer_model = BartForConditionalGeneration.from_pretrained('facebook/bart-large-cnn')
# Out:
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.58k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.63G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]

# %%
def summarize_text(text, max_length=150, min_length=50):
    inputs = summarizer_tokenizer.encode(text, return_tensors='pt', truncation=True)
    summary_ids = summarizer_model.generate(
        inputs,
        max_length=max_length,
        min_length=min_length,
        length_penalty=2.0,
        num_beams=4,
        early_stopping=True
    )
    summary = summarizer_tokenizer.decode(summary_ids[0], skip_special_tokens=True)
    return summary

# %% [markdown]
# # **Here we added text summerizer to enhance the user experience**

# %%
import ipywidgets as widgets
from IPython.display import display, HTML

prompt_widget = widgets.Text(
    value='Once upon a time in a land far away',
    description='Prompt:',
    style={'description_width': 'initial'}
)
max_length_widget = widgets.IntSlider(
    value=100,
    min=10,
    max=500,
    step=10,
    description='Max Length:',
    style={'description_width': 'initial'}
)
temperature_widget = widgets.FloatSlider(
    value=1.0,
    min=0.1,
    max=2.0,
    step=0.1,
    description='Temperature:',
    style={'description_width': 'initial'}
)

display(prompt_widget, max_length_widget, temperature_widget)

def on_button_click(b):
    prompt = prompt_widget.value
    max_length = max_length_widget.value
    temperature = temperature_widget.value

    generated_text = generate_text(prompt, max_length=max_length, temperature=temperature)
    summary = summarize_text(generated_text)

    styled_output = f"""
    <div style="font-family: Arial, sans-serif; padding: 10px; border: 1px solid #ddd; border-radius: 5px; margin-bottom: 20px;">
        <b>Prompt:</b> <span style="color: #007bff;">{prompt}</span><br>
        <b>Generated Text:</b> <span style="color: #333;">{generated_text}</span><br>
        <b>Summary:</b> <span style="color: #28a745;">{summary}</span>
    </div>
    """
    display(HTML(styled_output))

generate_button = widgets.Button(description="Generate and Summarize")
generate_button.on_click(on_button_click)
display(generate_button)
# Out:
# Text(value='Once upon a time in a land far away', description='Prompt:', style=DescriptionStyle(description_wi…
# IntSlider(value=100, description='Max Length:', max=500, min=10, step=10, style=SliderStyle(description_width=…
# FloatSlider(value=1.0, description='Temperature:', max=2.0, min=0.1, style=SliderStyle(description_width='init…
# Button(description='Generate and Summarize', style=ButtonStyle())
#     <div style="font-family: Arial, sans-serif; padding: 10px; border: 1px solid #ddd; border-radius: 5px; margin-bottom: 20px;">
#         <b>Prompt:</b> <span style="color: #007bff;">The Wall Of China</span><br>
#         <b>Generated Text:</b> <span style="color: #333;">The Wall Of China"
#
# "The Wall Of China"
#
# "The Wall Of China"
#
# "The Wall Of China"
#
# "The Wall Of China"
#
# "The Wall Of China"
#
# "The Wall Of China"
#
# "The Wall Of China"
#
# "The Wall Of China"
#
# "The Wall Of China"
#
# "The Wall Of China"
#
# "The Wall Of China"
#
# ...

# %%
# !pip install gtts

# %%
from gtts import gTTS
from IPython.display import Audio
import IPython.display as display

# %%
from gtts import gTTS
from IPython.display import Audio

def text_to_speech(text, lang='en'):

    tts = gTTS(text=text, lang=lang)

    audio_file = '/content/tts_output.mp3'
    tts.save(audio_file)

    return Audio(audio_file, autoplay=True)

# %% [markdown]
# **#We loved the idea of using *Text-To-Speech* idea so we added it here in this cell to improve the experience of the user with the module#**

# %%
import ipywidgets as widgets
from IPython.display import display, HTML

prompt_widget = widgets.Text(
    value='Once upon a time in a land far away',
    description='Prompt:',
    style={'description_width': 'initial'}
)
max_length_widget = widgets.IntSlider(
    value=100,
    min=10,
    max=500,
    step=10,
    description='Max Length:',
    style={'description_width': 'initial'}
)
temperature_widget = widgets.FloatSlider(
    value=1.0,
    min=0.1,
    max=2.0,
    step=0.1,
    description='Temperature:',
    style={'description_width': 'initial'}
)

display(prompt_widget, max_length_widget, temperature_widget)

def on_button_click(b):
    prompt = prompt_widget.value
    max_length = max_length_widget.value
    temperature = temperature_widget.value

    generated_text = generate_text(prompt, max_length=max_length, temperature=temperature)
    summary = summarize_text(generated_text)

    styled_output = f"""
    <div style="font-family: Arial, sans-serif; padding: 10px; border: 1px solid #ddd; border-radius: 5px; margin-bottom: 20px;">
        <b>Prompt:</b> <span style="color: #007bff;">{prompt}</span><br>
        <b>Generated Text:</b> <span style="color: #333;">{generated_text}</span><br>
        <b>Summary:</b> <span style="color: #28a745;">{summary}</span>
    </div>
    """
    display(HTML(styled_output))

    audio = text_to_speech(generated_text)
    display(audio)

    summary_audio = text_to_speech(summary)
    display(summary_audio)

generate_button = widgets.Button(description="Generate, Summarize, and Speak")
generate_button.on_click(on_button_click)
display(generate_button)
# Out:
# Text(value='Once upon a time in a land far away', description='Prompt:', style=DescriptionStyle(description_wi…
# IntSlider(value=100, description='Max Length:', max=500, min=10, step=10, style=SliderStyle(description_width=…
# FloatSlider(value=1.0, description='Temperature:', max=2.0, min=0.1, style=SliderStyle(description_width='init…
# Button(description='Generate, Summarize, and Speak', style=ButtonStyle())
#     <div style="font-family: Arial, sans-serif; padding: 10px; border: 1px solid #ddd; border-radius: 5px; margin-bottom: 20px;">
#         <b>Prompt:</b> <span style="color: #007bff;">Once upon a time in a land far away</span><br>
# ...
